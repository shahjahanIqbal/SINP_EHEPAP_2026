# %% [markdown]
# Here we will explore the structure of CTA Event files. We will use `h5py` to look at the directory structure and `ctapipe.io.EventSource` to load the same file for future analysis.\
# For a complete description of the dataset used here, refer [CTAO Monte Carlo Simulations - Eventlists on DL2 data level - prod5](https://zenodo.org/records/7298569?)

# %%
import numpy as np
import ctapipe
from ctapipe.io import EventSource
import h5py
from pprint import pprint


input_file = (
    "/home/shahjahan/Desktop/SINP_School/Data/"
    "gamma-diffuse_with_images_00.dl2.h5"
)

# %%
#with h5py.File(input_file, "r") as f:
#    f.visit(print)
#f.close()

# %% [markdown]
# #### Directory Structure Summarized
# <pre>
# configuration/
# |--> instrument/
# |    |--> subarray/
# |    |    |--> layout
# |    |--> telescope/
# |         |--> camera/
# |         |    |--> geometry (0,1)
# |         |    |--> readout (0,1)
# |         |--> optics
# |--> observation/
# |    |--> observation_block
# |    |--> scheduling_block
# |--> simulation/
#      |--> run
#
# dl1/
# |--> event/
# |    |--> subarray/
# |    |    |--> trigger
# |    |--> telescope/
# |         |--> images/
# |         |    |--> tel_XXX
# |         |--> parameters/
# |         |    |--> tel_XXX
# |         |--> trigger
# |--> monitoring/
# |    |--> subarray/
# |    |     |--> pointing
# |    |--> telescope/
# |         |--> pointing/
# |              |--> tel_XXX
# |--> service/
#      |--> image_statistics
#
# dl2/
# |--> event/
# |    |--> subarray/
# |    |    |--> geometry/
# |    |         |--> HillasReconstructor
# |    |--> telescope/
# |         |--> impact/
# |              |--> HillasReconstructor/
# |                   |--> tel_XXX
# |── service/
#     |--> tel_event_statistics/
#          |--> HillasReconstructor
#
# simulation/
# |--> event/
# |    |--> subarray/
# |    |    |--> shower
# |    |--> telescope/
# |         |--> images/
# |         |    |--> tel_XXX
# |         |--> impact/
# |         |    |--> tel_XXX
# |         |--> parameters/
# |              |--> tel_XXX
# |── service/
#     |--> shower_distribution
# </pre>
# ---

# %% [markdown]
# We create an instance of the `ctapipe.io.EventSource` that reads the input file and generate `ArrayEventContainer` instances iterated over each event.
# This is a top level container for all event info. The `EventSource` instance creates an `ArrayEventController` for each event that contains the index, dl1, dl2, simulation and trigger information

# %%
source = EventSource(
    input_url=input_file,
    max_events = 10 # Limit the number of events
)
# Out:
# Table /configuration/simulation/run is missing column None for field run_number of container <class 'ctapipe.containers.SimulationConfigContainer'>. It will be skipped.

# %%
source
# Out:
# <div style="border:1px solid black; max-width: 700px; padding:2em; word-wrap:break-word;">
# <b>HDF5EventSource</b>
# <div class="document">
# <p>Event source for files in the ctapipe DL1 format.
# For general information about the concept of event sources,
# take a look at the parent class ctapipe.io.EventSource.</p>
# <p>To use this event source, create an instance of this class
# specifying the file to be read.</p>
# <p>Looping over the EventSource yields events from the _generate_events
# method. An event equals an ArrayEventContainer instance.
# See ctapipe.containers.ArrayEventContainer for details.</p>
# <div class="section" id="attributes">
# <h1>Attributes</h1>
# <dl class="docutils">
# <dt>input_url: str</dt>
# <dd>Path to the input event file.</dd>
# <dt>file: tables.File</dt>
# <dd>File object</dd>
# <dt>obs_ids: list</dt>
# <dd>Observation ids of the recorded runs. For unmerged files, this
# should only contain a single number.</dd>
# <dt>subarray: ctapipe.instrument.SubarrayDescription</dt>
# <dd>The subarray configuration of the recorded run.</dd>
# <dt>datalevels: Tuple</dt>
# <dd>One or both of ctapipe.io.datalevels.DataLevel.DL1_IMAGES
# and ctapipe.io.datalevels.DataLevel.DL1_PARAMETERS
# depending on the information present in the file.</dd>
# <dt>is_simulation: Boolean</dt>
# <dd>Whether the events are simulated or observed.</dd>
# <dt>simulation_configs: Dict</dt>
# <dd>Mapping of obs_id to ctapipe.containers.SimulationConfigContainer
# if the file contains simulated events.</dd>
# <dt>has_simulated_dl1: Boolean</dt>
# <dd>Whether the file contains simulated camera images and/or
# image parameters evaluated on these.</dd>
# </dl>
# </div>
# </div>
#
# <table>
#     <colgroup>
#         <col span='1' style=' '>
#         <col span='1' style='width: 20em;'>
#         <col span='1' >
#     </colgroup>
#     <tbody>
# <tr><th>allowed_tels</th>
# <td style="text-align: left;">None</td>
# <td style="text-align: left;"><i>list of allowed tel_ids, others will be ignored. If None, all telescopes in the input stream will be included (default: None)</i></td></tr>
# <tr><th>focal_length_choice</th>
# <td style="text-align: left;">FocalLengthKind.EFFECTIVE</td>
# <td style="text-align: left;"><i>If both nominal and effective focal lengths are available,  which one to use for the `~ctapipe.coordinates.CameraFrame` attached to the `~ctapipe.instrument.CameraGeometry` instances in the `~ctapipe.instrument.SubarrayDescription` which will be used in CameraFrame to TelescopeFrame coordinate transforms. The &#x27;nominal&#x27; focal length is the one used during  the simulation, the &#x27;effective&#x27; focal length is computed using specialized  ray-tracing from a point light source (default: FocalLengthKind.EFFECTIVE)</i></td></tr>
# <tr><th>input_url</th>
# <td style="text-align: left;"><span style="color:blue; max-width:30em;">/<wbr>home/<wbr>shahjahan/<wbr>Desktop/<wbr>SINP_<wbr>School/<wbr>Data/<wbr>gamma-diffuse_<wbr>with_<wbr>images_<wbr>00.dl2.h5</span></td>
# <td style="text-align: left;"><i>Path to the input file containing events. (default: None)</i></td></tr>
# <tr><th>max_events</th>
# <td style="text-align: left;"><span style="color:blue; max-width:30em;">10</span></td>
# <td style="text-align: left;"><i>Maximum number of events that will be read from the file (default: None)</i></td></tr>
#     </tbody>
# </table>
# </div>

# %% [markdown]
# Accessing the telescope description

# %%
tel_dict = source.subarray.tel
pprint(tel_dict)
# Out:
# {np.int16(1): TelescopeDescription(type='LST', optics_name='LST', camera_name='LSTCam'),
#  np.int16(2): TelescopeDescription(type='LST', optics_name='LST', camera_name='LSTCam'),
#  np.int16(3): TelescopeDescription(type='LST', optics_name='LST', camera_name='LSTCam'),
#  np.int16(4): TelescopeDescription(type='LST', optics_name='LST', camera_name='LSTCam'),
#  np.int16(5): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(6): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(7): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(8): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(9): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(10): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(11): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(19): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(35): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam')}

# %%
for event in source:
    print(event.index.event_id)
# Out:
# Table /dl1/event/telescope/trigger is missing column event_type for field event_type of container <class 'ctapipe.containers.TelescopeTriggerContainer'>. It will be skipped.
# Table /simulation/event/subarray/shower is missing column true_starting_grammage for field starting_grammage of container <class 'ctapipe.containers.SimulatedShowerContainer'>. It will be skipped.
# Table /dl2/event/subarray/geometry/HillasReconstructor is missing column HillasReconstructor_ang_distance_uncert for field ang_distance_uncert of container <class 'ctapipe.containers.ReconstructedGeometryContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_035 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_035 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_035 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_035 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_010 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_010 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_010 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_010 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_011 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_011 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_011 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_011 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_009 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_009 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_009 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_009 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_007 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_007 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_007 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_007 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_005 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_005 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_005 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_005 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_001 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_001 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_001 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_001 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_002 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_002 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_002 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_002 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_008 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_008 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_008 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_008 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_019 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_019 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_019 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_019 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_003 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_003 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_003 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_003 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# 74802
# 74804
# 80503
# 117304
# 117308
# 117314
# 148511
# 157711
# 161518
# Table /dl1/event/telescope/parameters/tel_004 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_004 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_004 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_004 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# 165406

# %% [markdown]
# Structure of the `ArrayEventContainer`

# %%
event
# Out:
# ctapipe.containers.ArrayEventContainer:
#                        index.*: event indexing information with default None
#                           r0.*: Raw Data with default None
#                           r1.*: R1 Calibrated Data with default None
#                          dl0.*: DL0 Data Volume Reduced Data with default None
#                          dl1.*: DL1 Calibrated image with default None
#                          dl2.*: DL2 reconstruction info with default None
#                   simulation.*: Simulated Event Information with default None
#                                 with type <class
#                                 'ctapipe.containers.SimulatedEventContainer'>
#                      trigger.*: central trigger information with default None
#                          count: number of events processed with default 0
#                   monitoring.*: container for event-wise monitoring data (MON)
#                                 with default None
#                         muon.*: Container for muon analysis results with default
#                                 None

# %% [markdown]
# `dl1` contains the calibrated image and `dl2` has the reconstructed parameters. `simulation` contains the shower simulation parameters
# Refer to [ctapipe documentation](https://ctapipe.readthedocs.io/en/latest/user-guide/data_format/index.html) for more details

# %%
print(event.dl1)
# Out:
# {'tel': {np.int16(1): {'image': array([-0.7, -1.5,  0.5, ...,  0.6, -1.1, -0.7],
#       shape=(1855,), dtype=float32),
#                        'image_mask': array([False, False, False, ..., False, False, False], shape=(1855,)),
#                        'is_valid': np.True_,
#                        'parameters': {'concentration': {'cog': np.float64(0.557393919693173),
#                                                         'core': np.float64(0.39182990927330263),
#                                                         'pixel': np.float64(0.21281184675569859)},
#                                       'core': {'psi': <Quantity nan deg>},
#                                       'hillas': {'fov_lat': <Quantity -0.38510406 deg>,
#                                                  'fov_lon': <Quantity 1.17954078 deg>,
#                                                  'intensity': np.float64(54.234540939331055),
#                                                  'kurtosis': np.float64(2.4527596180683475),
#                                                  'length': <Quantity 0.07977715 deg>,
#                                                  'length_uncertainty': <Quantity 0.00652841 deg>,
#                                                  'phi': <Quantity -18.08115788 deg>,
#                                                  'psi': <Quantity 3.69128163 deg>,
#                                                  'psi_uncertainty': None,
#                                                  'r': <Quantity 1.24081488 deg>,
#                                                  'skewness': np.float64(-0.14862657310234745),
#                                                  'transverse_cog_uncertainty': None,
#                                                  'width': <Quantity 0.05068507 deg>,
#                                                  'width_uncertainty': <Quantity 0.00384711 deg>},
#                                       'intensity_statistics': {'kurtosis': np.float64(-1.1485446691513062),
#                                                                'max': np.float32(11.541753),
#                                                                'mean': np.float32(7.747792),
#                                                                'min': np.float32(4.80531),
#                                                                'skewness': np.float64(0.31160661578178406),
#                                                                'std': np.float32(2.245624)},
#                                       'leakage': {'intensity_width_1': np.float32(0.0),
#                                                   'intensity_width_2': np.float32(0.0),
#                                                   'pixels_width_1': np.float64(0.0),
#                                                   'pixels_width_2': np.float64(0.0)},
#                                       'morphology': {'n_islands': np.int64(1),
#                                                      'n_large_islands': np.int64(0),
#                                                      'n_medium_islands': np.int64(1),
#                                                      'n_pixels': np.int64(7),
#                                                      'n_small_islands': np.int64(0)},
#                                       'peak_time_statistics': {'kurtosis': np.float64(0.6271548271179199),
#                                                                'max': np.float32(16.098234),
#                                                                'mean': np.float32(11.464106),
#                                                                'min': np.float32(9.362585),
#                                                                'skewness': np.float64(1.298380970954895),
#                                                                'std': np.float32(2.0984054)},
#                                       'timing': {'deviation': np.float64(2.0880623537929073),
#                                                  'intercept': np.float64(10.516694086285039),
#                                                  'slope': <Quantity -10.78045305 1 / deg>}},
#                        'peak_time': array([ 4.46, 22.1 , 14.12, ..., 37.75, 36.82, 33.18],
#       shape=(1855,), dtype=float32)},
#          np.int16(2): {'image': array([-2. , -0.7, -0.5, ...,  0.6,  0.8,  0.4],
#       shape=(1855,), dtype=float32),
#                        'image_mask': array([False, False, False, ..., False, False, False], shape=(1855,)),
#                        'is_valid': np.True_,
#                        'parameters': {'concentration': {'cog': np.float64(0.048989545694361425),
#                                                         'core': np.float64(0.2851422489632416),
#                                                         'pixel': np.float64(0.15605488390463818)},
#                                       'core': {'psi': <Quantity nan deg>},
#                                       'hillas': {'fov_lat': <Quantity -0.60076374 deg>,
#                                                  'fov_lon': <Quantity 0.93572749 deg>,
#                                                  'intensity': np.float64(110.27186870574951),
#                                                  'kurtosis': np.float64(1.2962378830974608),
#                                                  'length': <Quantity 0.19685572 deg>,
#                                                  'length_uncertainty': <Quantity 0.00510159 deg>,
#                                                  'phi': <Quantity -32.70161996 deg>,
#                                                  'psi': <Quantity 18.23296936 deg>,
#                                                  'psi_uncertainty': None,
#                                                  'r': <Quantity 1.11198157 deg>,
#                                                  'skewness': np.float64(-0.014258722386058756),
#                                                  'transverse_cog_uncertainty': None,
#                                                  'width': <Quantity 0.05829713 deg>,
#                                                  'width_uncertainty': <Quantity 0.00265194 deg>},
#                                       'intensity_statistics': {'kurtosis': np.float64(-0.06314754486083984),
#                                                                'max': np.float32(17.208464),
#                                                                'mean': np.float32(10.024716),
#                                                                'min': np.float32(5.4021688),
#                                                                'skewness': np.float64(0.8743777871131897),
#                                                                'std': np.float32(3.2731051)},
#                                       'leakage': {'intensity_width_1': np.float32(0.0),
#                                                   'intensity_width_2': np.float32(0.0),
#                                                   'pixels_width_1': np.float64(0.0),
#                                                   'pixels_width_2': np.float64(0.0)},
#                                       'morphology': {'n_islands': np.int64(2),
#                                                      'n_large_islands': np.int64(0),
#                                                      'n_medium_islands': np.int64(2),
#                                                      'n_pixels': np.int64(11),
#                                                      'n_small_islands': np.int64(0)},
#                                       'peak_time_statistics': {'kurtosis': np.float64(-1.6992805004119873),
#                                                                'max': np.float32(36.028637),
#                                                                'mean': np.float32(28.188848),
#                                                                'min': np.float32(21.755774),
#                                                                'skewness': np.float64(0.26615944504737854),
#                                                                'std': np.float32(5.565603)},
#                                       'timing': {'deviation': np.float64(0.8070049833619246),
#                                                  'intercept': np.float64(28.314632333228978),
#                                                  'slope': <Quantity -29.9612227 1 / deg>}},
#                        'peak_time': array([24.41, 24.05, 36.11, ..., 10.02, 37.53, 37.73],
#       shape=(1855,), dtype=float32)},
#          np.int16(3): {'image': array([-1.3,  0.6, -1.1, ..., -1.3,  0.2,  2.1],
#       shape=(1855,), dtype=float32),
#                        'image_mask': array([False, False, False, ..., False, False, False], shape=(1855,)),
#                        'is_valid': np.True_,
#                        'parameters': {'concentration': {'cog': np.float64(0.0),
#                                                         'core': np.float64(0.23575896452050446),
#                                                         'pixel': np.float64(0.08395077341386342)},
#                                       'core': {'psi': <Quantity nan deg>},
#                                       'hillas': {'fov_lat': <Quantity 0.31327954 deg>,
#                                                  'fov_lon': <Quantity 1.11633708 deg>,
#                                                  'intensity': np.float64(216.84900093078613),
#                                                  'kurtosis': np.float64(1.499526840470504),
#                                                  'length': <Quantity 0.36469256 deg>,
#                                                  'length_uncertainty': <Quantity 0.0087518 deg>,
#                                                  'phi': <Quantity 15.67580183 deg>,
#                                                  'psi': <Quantity 16.96271283 deg>,
#                                                  'psi_uncertainty': None,
#                                                  'r': <Quantity 1.15946218 deg>,
#                                                  'skewness': np.float64(-0.10448478767861902),
#                                                  'transverse_cog_uncertainty': None,
#                                                  'width': <Quantity 0.06274525 deg>,
#                                                  'width_uncertainty': <Quantity 0.00284694 deg>},
#                                       'intensity_statistics': {'kurtosis': np.float64(-0.631920337677002),
#                                                                'max': np.float32(18.204641),
#                                                                'mean': np.float32(10.326143),
#                                                                'min': np.float32(4.8917007),
#                                                                'skewness': np.float64(0.49419283866882324),
#                                                                'std': np.float32(3.8760688)},
#                                       'leakage': {'intensity_width_1': np.float32(0.0),
#                                                   'intensity_width_2': np.float32(0.0),
#                                                   'pixels_width_1': np.float64(0.0),
#                                                   'pixels_width_2': np.float64(0.0)},
#                                       'morphology': {'n_islands': np.int64(2),
#                                                      'n_large_islands': np.int64(0),
#                                                      'n_medium_islands': np.int64(2),
#                                                      'n_pixels': np.int64(21),
#                                                      'n_small_islands': np.int64(0)},
#                                       'peak_time_statistics': {'kurtosis': np.float64(-1.5541107654571533),
#                                                                'max': np.float32(35.831696),
#                                                                'mean': np.float32(20.105816),
#                                                                'min': np.float32(2.9919918),
#                                                                'skewness': np.float64(-0.11627844721078873),
#                                                                'std': np.float32(11.398782)},
#                                       'timing': {'deviation': np.float64(1.3268808954997036),
#                                                  'intercept': np.float64(18.48018850162919),
#                                                  'slope': <Quantity -29.13148797 1 / deg>}},
#                        'peak_time': array([35.48, 18.29, 10.85, ...,  8.59,  6.07, 26.11],
#       shape=(1855,), dtype=float32)},
#          np.int16(4): {'image': array([ 0.2,  0.1,  0.9, ..., -0.2,  1.1,  1.8],
#       shape=(1855,), dtype=float32),
#                        'image_mask': array([False, False, False, ..., False, False, False], shape=(1855,)),
#                        'is_valid': np.True_,
#                        'parameters': {'concentration': {'cog': np.float64(0.40366937686791704),
#                                                         'core': np.float64(0.20280555819040938),
#                                                         'pixel': np.float64(0.2008637981794552)},
#                                       'core': {'psi': <Quantity nan deg>},
#                                       'hillas': {'fov_lat': <Quantity 0.25082341 deg>,
#                                                  'fov_lon': <Quantity 1.05067393 deg>,
#                                                  'intensity': np.float64(93.05023670196533),
#                                                  'kurtosis': np.float64(2.183264783109177),
#                                                  'length': <Quantity 0.09749243 deg>,
#                                                  'length_uncertainty': <Quantity 0.00549697 deg>,
#                                                  'phi': <Quantity 13.42670537 deg>,
#                                                  'psi': <Quantity 27.89163983 deg>,
#                                                  'psi_uncertainty': None,
#                                                  'r': <Quantity 1.08019817 deg>,
#                                                  'skewness': np.float64(0.12272123670769408),
#                                                  'transverse_cog_uncertainty': None,
#                                                  'width': <Quantity 0.0563394 deg>,
#                                                  'width_uncertainty': <Quantity 0.00408956 deg>},
#                                       'intensity_statistics': {'kurtosis': np.float64(-0.6318960189819336),
#                                                                'max': np.float32(18.690424),
#                                                                'mean': np.float32(10.338915),
#                                                                'min': np.float32(4.7994566),
#                                                                'skewness': np.float64(0.7514092326164246),
#                                                                'std': np.float32(4.6393633)},
#                                       'leakage': {'intensity_width_1': np.float32(0.0),
#                                                   'intensity_width_2': np.float32(0.0),
#                                                   'pixels_width_1': np.float64(0.0),
#                                                   'pixels_width_2': np.float64(0.0)},
#                                       'morphology': {'n_islands': np.int64(1),
#                                                      'n_large_islands': np.int64(0),
#                                                      'n_medium_islands': np.int64(1),
#                                                      'n_pixels': np.int64(9),
#                                                      'n_small_islands': np.int64(0)},
#                                       'peak_time_statistics': {'kurtosis': np.float64(-0.3193371295928955),
#                                                                'max': np.float32(11.251024),
#                                                                'mean': np.float32(8.051404),
#                                                                'min': np.float32(2.2767806),
#                                                                'skewness': np.float64(-0.9770390391349792),
#                                                                'std': np.float32(2.7917743)},
#                                       'timing': {'deviation': np.float64(1.7156162294101112),
#                                                  'intercept': np.float64(7.229319974125026),
#                                                  'slope': <Quantity -23.02285967 1 / deg>}},
#                        'peak_time': array([35.24, 19.65, 35.39, ..., 20.27, 20.31, 19.9 ],
#       shape=(1855,), dtype=float32)},
#          np.int16(7): {'image': array([ 0.1, -0.6,  0.7, ...,  0.4,  4.2,  0. ],
#       shape=(1855,), dtype=float32),
#                        'image_mask': array([False, False, False, ..., False, False, False], shape=(1855,)),
#                        'is_valid': np.True_,
#                        'parameters': {'concentration': {'cog': np.float64(0.525322675843199),
#                                                         'core': np.float64(0.4013869623828978),
#                                                         'pixel': np.float64(0.16250398462231294)},
#                                       'core': {'psi': <Quantity nan deg>},
#                                       'hillas': {'fov_lat': <Quantity 0.20891028 deg>,
#                                                  'fov_lon': <Quantity 2.65436811 deg>,
#                                                  'intensity': np.float64(108.7181077003479),
#                                                  'kurtosis': np.float64(1.9300733881618075),
#                                                  'length': <Quantity 0.19437758 deg>,
#                                                  'length_uncertainty': <Quantity 0.00898926 deg>,
#                                                  'phi': <Quantity 4.50014982 deg>,
#                                                  'psi': <Quantity 24.55791983 deg>,
#                                                  'psi_uncertainty': None,
#                                                  'r': <Quantity 2.66257649 deg>,
#                                                  'skewness': np.float64(-0.1556562328787208),
#                                                  'transverse_cog_uncertainty': None,
#                                                  'width': <Quantity 0.0923735 deg>,
#                                                  'width_uncertainty': <Quantity 0.00567258 deg>},
#                                       'intensity_statistics': {'kurtosis': np.float64(-1.329067587852478),
#                                                                'max': np.float32(17.667126),
#                                                                'mean': np.float32(10.871811),
#                                                                'min': np.float32(5.205086),
#                                                                'skewness': np.float64(0.20969443023204803),
#                                                                'std': np.float32(4.2470937)},
#                                       'leakage': {'intensity_width_1': np.float32(0.0),
#                                                   'intensity_width_2': np.float32(0.0),
#                                                   'pixels_width_1': np.float64(0.0),
#                                                   'pixels_width_2': np.float64(0.0)},
#                                       'morphology': {'n_islands': np.int64(1),
#                                                      'n_large_islands': np.int64(0),
#                                                      'n_medium_islands': np.int64(1),
#                                                      'n_pixels': np.int64(10),
#                                                      'n_small_islands': np.int64(0)},
#                                       'peak_time_statistics': {'kurtosis': np.float64(-1.511252522468567),
#                                                                'max': np.float32(15.77592),
#                                                                'mean': np.float32(9.697935),
#                                                                'min': np.float32(3.5991075),
#                                                                'skewness': np.float64(0.03955674171447754),
#                                                                'std': np.float32(4.484552)},
#                                       'timing': {'deviation': np.float64(1.27659923733068),
#                                                  'intercept': np.float64(9.074816890756864),
#                                                  'slope': <Quantity -20.34136338 1 / deg>}},
#                        'peak_time': array([15.35, 45.47, 41.67, ..., 35.57,  3.27,  4.61],
#       shape=(1855,), dtype=float32)},
#          np.int16(8): {'image': array([ 1.3,  0.5, -0.5, ..., -0.2,  1.2, -0.3],
#       shape=(1855,), dtype=float32),
#                        'image_mask': array([False, False, False, ..., False, False, False], shape=(1855,)),
#                        'is_valid': np.True_,
#                        'parameters': {'concentration': {'cog': np.float64(0.7814252561581763),
#                                                         'core': np.float64(0.2160560779052729),
#                                                         'pixel': np.float64(0.23941236740425023)},
#                                       'core': {'psi': <Quantity nan deg>},
#                                       'hillas': {'fov_lat': <Quantity 1.22291689 deg>,
#                                                  'fov_lon': <Quantity 1.81489602 deg>,
#                                                  'intensity': np.float64(51.374422550201416),
#                                                  'kurtosis': np.float64(1.462741479036835),
#                                                  'length': <Quantity 0.12478026 deg>,
#                                                  'length_uncertainty': <Quantity 0.00592123 deg>,
#                                                  'phi': <Quantity 33.97295714 deg>,
#                                                  'psi': <Quantity 18.76190868 deg>,
#                                                  'psi_uncertainty': None,
#                                                  'r': <Quantity 2.18846368 deg>,
#                                                  'skewness': np.float64(-0.037281407321371855),
#                                                  'transverse_cog_uncertainty': None,
#                                                  'width': <Quantity 0.08184958 deg>,
#                                                  'width_uncertainty': <Quantity 0.00581144 deg>},
#                                       'intensity_statistics': {'kurtosis': np.float64(-1.9344946146011353),
#                                                                'max': np.float32(12.299672),
#                                                                'mean': np.float32(8.562404),
#                                                                'min': np.float32(5.1081214),
#                                                                'skewness': np.float64(0.024029701948165894),
#                                                                'std': np.float32(3.1425362)},
#                                       'leakage': {'intensity_width_1': np.float32(0.0),
#                                                   'intensity_width_2': np.float32(0.0),
#                                                   'pixels_width_1': np.float64(0.0),
#                                                   'pixels_width_2': np.float64(0.0)},
#                                       'morphology': {'n_islands': np.int64(1),
#                                                      'n_large_islands': np.int64(0),
#                                                      'n_medium_islands': np.int64(1),
#                                                      'n_pixels': np.int64(6),
#                                                      'n_small_islands': np.int64(0)},
#                                       'peak_time_statistics': {'kurtosis': np.float64(-1.2543505430221558),
#                                                                'max': np.float32(16.726503),
#                                                                'mean': np.float32(14.836417),
#                                                                'min': np.float32(13.332756),
#                                                                'skewness': np.float64(0.38322004675865173),
#                                                                'std': np.float32(1.1913898)},
#                                       'timing': {'deviation': np.float64(0.3889138841427192),
#                                                  'intercept': np.float64(14.672418214294135),
#                                                  'slope': <Quantity -7.93215074 1 / deg>}},
#                        'peak_time': array([30.85, 31.16, 32.76, ..., 36.43, 43.76, 40.11],
#       shape=(1855,), dtype=float32)}}}

# %%
print(event.dl2)
# Out:
# {'stereo': {'classification': {},
#             'energy': {},
#             'geometry': {'HillasReconstructor': {'alt': <Quantity 70.50306184 deg>,
#                                                  'alt_uncert': <Quantity 12.40947121 deg>,
#                                                  'ang_distance_uncert': None,
#                                                  'average_intensity': np.float64(105.74969625473022),
#                                                  'az': <Quantity 9.75160898 deg>,
#                                                  'az_uncert': <Quantity 12.40947121 deg>,
#                                                  'core_tilted_uncert_x': <Quantity nan m>,
#                                                  'core_tilted_uncert_y': <Quantity nan m>,
#                                                  'core_tilted_x': <Quantity -59.45111327 m>,
#                                                  'core_tilted_y': <Quantity -188.27250469 m>,
#                                                  'core_uncert_x': <Quantity nan m>,
#                                                  'core_uncert_y': <Quantity nan m>,
#                                                  'core_x': <Quantity -63.26655342 m>,
#                                                  'core_y': <Quantity -188.27250469 m>,
#                                                  'goodness_of_fit': np.float64(nan),
#                                                  'h_max': <Quantity 6988.29029944 m>,
#                                                  'h_max_uncert': <Quantity nan m>,
#                                                  'is_valid': np.True_,
#                                                  'telescopes': array([ True,  True,  True,  True, False, False,  True,  True, False,
#        False, False, False, False])}}},
#  'tel': {np.int16(1): {'classification': {},
#                        'disp': {},
#                        'energy': {},
#                        'geometry': {},
#                        'impact': {'HillasReconstructor': {'distance': <Quantity 139.78524582 m>,
#                                                           'distance_uncert': <Quantity nan m>}}},
#          np.int16(2): {'classification': {},
#                        'disp': {},
#                        'energy': {},
#                        'geometry': {},
#                        'impact': {'HillasReconstructor': {'distance': <Quantity 256.72734443 m>,
#                                                           'distance_uncert': <Quantity nan m>}}},
#          np.int16(3): {'classification': {},
#                        'disp': {},
#                        'energy': {},
#                        'geometry': {},
#                        'impact': {'HillasReconstructor': {'distance': <Quantity 271.1642724 m>,
#                                                           'distance_uncert': <Quantity nan m>}}},
#          np.int16(4): {'classification': {},
#                        'disp': {},
#                        'energy': {},
#                        'geometry': {},
#                        'impact': {'HillasReconstructor': {'distance': <Quantity 149.23443991 m>,
#                                                           'distance_uncert': <Quantity nan m>}}},
#          np.int16(7): {'classification': {},
#                        'disp': {},
#                        'energy': {},
#                        'geometry': {},
#                        'impact': {'HillasReconstructor': {'distance': <Quantity 397.10327018 m>,
#                                                           'distance_uncert': <Quantity nan m>}}},
#          np.int16(8): {'classification': {},
#                        'disp': {},
#                        'energy': {},
#                        'geometry': {},
#                        'impact': {'HillasReconstructor': {'distance': <Quantity 346.71677862 m>,
#                                                           'distance_uncert': <Quantity nan m>}}}}}

# %%
print(event.simulation)
# Out:
# {'shower': {'alt': <Quantity 70.69673361 deg>,
#             'az': <Quantity 27.80644631 deg>,
#             'core_x': <Quantity 410.42434692 m>,
#             'core_y': <Quantity 1080.73254395 m>,
#             'energy': <Quantity 58.88951111 TeV>,
#             'h_first_int': <Quantity 28967.98242188 m>,
#             'shower_primary_id': np.int64(0),
#             'starting_grammage': None,
#             'x_max': <Quantity 375.32244873 g / cm2>},
#  'tel': {np.int16(1): {'impact': {'distance': <Quantity 1229.32473932 m>,
#                                   'distance_uncert': <Quantity 0. m>},
#                        'true_image': array([0, 0, 0, ..., 0, 0, 0], shape=(1855,), dtype=int32),
#                        'true_image_sum': 1493,
#                        'true_parameters': {'concentration': {'cog': np.float64(0.01808439383791025),
#                                                              'core': np.float64(0.39986604152712657),
#                                                              'pixel': np.float64(0.010716677829872739)},
#                                            'core': {'psi': <Quantity nan deg>},
#                                            'hillas': {'fov_lat': <Quantity -0.76703625 deg>,
#                                                       'fov_lon': <Quantity 0.30466142 deg>,
#                                                       'intensity': np.float64(1493.0),
#                                                       'kurtosis': np.float64(1.848114931942647),
#                                                       'length': <Quantity 1.11355821 deg>,
#                                                       'length_uncertainty': <Quantity 0.01327029 deg>,
#                                                       'phi': <Quantity -68.33737085 deg>,
#                                                       'psi': <Quantity 21.26284235 deg>,
#                                                       'psi_uncertainty': None,
#                                                       'r': <Quantity 0.82532611 deg>,
#                                                       'skewness': np.float64(-0.1008091547672371),
#                                                       'transverse_cog_uncertainty': None,
#                                                       'width': <Quantity 0.26068202 deg>,
#                                                       'width_uncertainty': <Quantity 0.00924747 deg>},
#                                            'intensity_statistics': {'kurtosis': np.float64(2.0503603796869356),
#                                                                     'max': np.int32(16),
#                                                                     'mean': np.float64(3.5212264150943398),
#                                                                     'min': np.int32(1),
#                                                                     'skewness': np.float64(1.5188167663987917),
#                                                                     'std': np.float64(3.1718874812986706)},
#                                            'leakage': {'intensity_width_1': np.float64(0.04420629604822505),
#                                                        'intensity_width_2': np.float64(0.09377093101138648),
#                                                        'pixels_width_1': np.float64(0.01078167115902965),
#                                                        'pixels_width_2': np.float64(0.024797843665768194)},
#                                            'morphology': {'n_islands': np.int64(32),
#                                                           'n_large_islands': np.int64(1),
#                                                           'n_medium_islands': np.int64(3),
#                                                           'n_pixels': np.int64(424),
#                                                           'n_small_islands': np.int64(28)},
#                                            'peak_time_statistics': {'kurtosis': nan,
#                                                                     'max': np.float32(nan),
#                                                                     'mean': np.float32(nan),
#                                                                     'min': np.float32(nan),
#                                                                     'skewness': nan,
#                                                                     'std': np.float32(nan)},
#                                            'timing': {'deviation': nan,
#                                                       'intercept': nan,
#                                                       'slope': <Quantity nan 1 / deg>}}},
#          np.int16(2): {'impact': {'distance': <Quantity 1107.19989885 m>,
#                                   'distance_uncert': <Quantity 0. m>},
#                        'true_image': array([0, 0, 0, ..., 0, 0, 0], shape=(1855,), dtype=int32),
#                        'true_image_sum': 2181,
#                        'true_parameters': {'concentration': {'cog': np.float64(0.016506189821182942),
#                                                              'core': np.float64(0.4076111875286566),
#                                                              'pixel': np.float64(0.012838147638697846)},
#                                            'core': {'psi': <Quantity nan deg>},
#                                            'hillas': {'fov_lat': <Quantity -0.77666128 deg>,
#                                                       'fov_lon': <Quantity 0.42621993 deg>,
#                                                       'intensity': np.float64(2181.0),
#                                                       'kurtosis': np.float64(1.9317373803547429),
#                                                       'length': <Quantity 1.09357013 deg>,
#                                                       'length_uncertainty': <Quantity 0.01130149 deg>,
#                                                       'phi': <Quantity -61.24268814 deg>,
#                                                       'psi': <Quantity 22.51209127 deg>,
#                                                       'psi_uncertainty': None,
#                                                       'r': <Quantity 0.88592673 deg>,
#                                                       'skewness': np.float64(-0.1191366629987309),
#                                                       'transverse_cog_uncertainty': None,
#                                                       'width': <Quantity 0.293933 deg>,
#                                                       'width_uncertainty': <Quantity 0.00921945 deg>},
#                                            'intensity_statistics': {'kurtosis': np.float64(3.634040229356133),
#                                                                     'max': np.int32(28),
#                                                                     'mean': np.float64(4.451020408163266),
#                                                                     'min': np.int32(1),
#                                                                     'skewness': np.float64(1.717568658640506),
#                                                                     'std': np.float64(4.195557536299535)},
#                                            'leakage': {'intensity_width_1': np.float64(0.04722604309949564),
#                                                        'intensity_width_2': np.float64(0.10545621274644658),
#                                                        'pixels_width_1': np.float64(0.014555256064690027),
#                                                        'pixels_width_2': np.float64(0.030727762803234502)},
#                                            'morphology': {'n_islands': np.int64(41),
#                                                           'n_large_islands': np.int64(1),
#                                                           'n_medium_islands': np.int64(8),
#                                                           'n_pixels': np.int64(490),
#                                                           'n_small_islands': np.int64(32)},
#                                            'peak_time_statistics': {'kurtosis': nan,
#                                                                     'max': np.float32(nan),
#                                                                     'mean': np.float32(nan),
#                                                                     'min': np.float32(nan),
#                                                                     'skewness': nan,
#                                                                     'std': np.float32(nan)},
#                                            'timing': {'deviation': nan,
#                                                       'intercept': nan,
#                                                       'slope': <Quantity nan 1 / deg>}}},
#          np.int16(3): {'impact': {'distance': <Quantity 1080.18891283 m>,
#                                   'distance_uncert': <Quantity 0. m>},
#                        'true_image': array([20, 12,  9, ...,  0,  3,  0], shape=(1855,), dtype=int32),
#                        'true_image_sum': 2820,
#                        'true_parameters': {'concentration': {'cog': np.float64(0.015602836879432624),
#                                                              'core': np.float64(0.44468085106382976),
#                                                              'pixel': np.float64(0.008865248226950355)},
#                                            'core': {'psi': <Quantity nan deg>},
#                                            'hillas': {'fov_lat': <Quantity 0.03275032 deg>,
#                                                       'fov_lon': <Quantity 0.21092562 deg>,
#                                                       'intensity': np.float64(2820.0),
#                                                       'kurtosis': np.float64(1.9813895642489097),
#                                                       'length': <Quantity 1.19064812 deg>,
#                                                       'length_uncertainty': <Quantity 0.01110579 deg>,
#                                                       'phi': <Quantity 8.82581272 deg>,
#                                                       'psi': <Quantity 17.40476571 deg>,
#                                                       'psi_uncertainty': None,
#                                                       'r': <Quantity 0.21345304 deg>,
#                                                       'skewness': np.float64(-0.22503454106645598),
#                                                       'transverse_cog_uncertainty': None,
#                                                       'width': <Quantity 0.3143197 deg>,
#                                                       'width_uncertainty': <Quantity 0.00988632 deg>},
#                                            'intensity_statistics': {'kurtosis': np.float64(3.3800148743153002),
#                                                                     'max': np.int32(25),
#                                                                     'mean': np.float64(4.600326264274062),
#                                                                     'min': np.int32(1),
#                                                                     'skewness': np.float64(1.8370130090779306),
#                                                                     'std': np.float64(4.5758212582212465)},
#                                            'leakage': {'intensity_width_1': np.float64(0.03226950354609929),
#                                                        'intensity_width_2': np.float64(0.07021276595744681),
#                                                        'pixels_width_1': np.float64(0.015633423180592992),
#                                                        'pixels_width_2': np.float64(0.030727762803234502)},
#                                            'morphology': {'n_islands': np.int64(52),
#                                                           'n_large_islands': np.int64(1),
#                                                           'n_medium_islands': np.int64(14),
#                                                           'n_pixels': np.int64(613),
#                                                           'n_small_islands': np.int64(37)},
#                                            'peak_time_statistics': {'kurtosis': nan,
#                                                                     'max': np.float32(nan),
#                                                                     'mean': np.float32(nan),
#                                                                     'min': np.float32(nan),
#                                                                     'skewness': nan,
#                                                                     'std': np.float32(nan)},
#                                            'timing': {'deviation': nan,
#                                                       'intercept': nan,
#                                                       'slope': <Quantity nan 1 / deg>}}},
#          np.int16(4): {'impact': {'distance': <Quantity 1203.12889345 m>,
#                                   'distance_uncert': <Quantity 0. m>},
#                        'true_image': array([ 9, 11,  5, ...,  0,  0,  2], shape=(1855,), dtype=int32),
#                        'true_image_sum': 1828,
#                        'true_parameters': {'concentration': {'cog': np.float64(0.013676148796498906),
#                                                              'core': np.float64(0.4217724288840263),
#                                                              'pixel': np.float64(0.013676148796498906)},
#                                            'core': {'psi': <Quantity nan deg>},
#                                            'hillas': {'fov_lat': <Quantity -0.05640189 deg>,
#                                                       'fov_lon': <Quantity 0.08354879 deg>,
#                                                       'intensity': np.float64(1828.0),
#                                                       'kurtosis': np.float64(1.8495055894906534),
#                                                       'length': <Quantity 1.22446294 deg>,
#                                                       'length_uncertainty': <Quantity 0.01319808 deg>,
#                                                       'phi': <Quantity -34.02239431 deg>,
#                                                       'psi': <Quantity 17.07263612 deg>,
#                                                       'psi_uncertainty': None,
#                                                       'r': <Quantity 0.10080463 deg>,
#                                                       'skewness': np.float64(-0.005852163652646435),
#                                                       'transverse_cog_uncertainty': None,
#                                                       'width': <Quantity 0.28291762 deg>,
#                                                       'width_uncertainty': <Quantity 0.01014437 deg>},
#                                            'intensity_statistics': {'kurtosis': np.float64(5.604086141803897),
#                                                                     'max': np.int32(25),
#                                                                     'mean': np.float64(3.7459016393442623),
#                                                                     'min': np.int32(1),
#                                                                     'skewness': np.float64(2.0619332972177915),
#                                                                     'std': np.float64(3.5645372527707933)},
#                                            'leakage': {'intensity_width_1': np.float64(0.03446389496717724),
#                                                        'intensity_width_2': np.float64(0.07713347921225383),
#                                                        'pixels_width_1': np.float64(0.011320754716981131),
#                                                        'pixels_width_2': np.float64(0.023180592991913745)},
#                                            'morphology': {'n_islands': np.int64(48),
#                                                           'n_large_islands': np.int64(1),
#                                                           'n_medium_islands': np.int64(11),
#                                                           'n_pixels': np.int64(488),
#                                                           'n_small_islands': np.int64(36)},
#                                            'peak_time_statistics': {'kurtosis': nan,
#                                                                     'max': np.float32(nan),
#                                                                     'mean': np.float32(nan),
#                                                                     'min': np.float32(nan),
#                                                                     'skewness': nan,
#                                                                     'std': np.float32(nan)},
#                                            'timing': {'deviation': nan,
#                                                       'intercept': nan,
#                                                       'slope': <Quantity nan 1 / deg>}}},
#          np.int16(7): {'impact': {'distance': <Quantity 961.1542531 m>,
#                                   'distance_uncert': <Quantity 0. m>},
#                        'true_image': array([0, 0, 0, ..., 0, 0, 0], shape=(1855,), dtype=int32),
#                        'true_image_sum': 1582,
#                        'true_parameters': {'concentration': {'cog': np.float64(0.01706700379266751),
#                                                              'core': np.float64(0.48166877370417194),
#                                                              'pixel': np.float64(0.020859671302149177)},
#                                            'core': {'psi': <Quantity nan deg>},
#                                            'hillas': {'fov_lat': <Quantity -0.5313986 deg>,
#                                                       'fov_lon': <Quantity 0.86087768 deg>,
#                                                       'intensity': np.float64(1582.0),
#                                                       'kurtosis': np.float64(2.2570187473781886),
#                                                       'length': <Quantity 1.92266468 deg>,
#                                                       'length_uncertainty': <Quantity 0.02709825 deg>,
#                                                       'phi': <Quantity -31.68601204 deg>,
#                                                       'psi': <Quantity 22.20045611 deg>,
#                                                       'psi_uncertainty': None,
#                                                       'r': <Quantity 1.01167922 deg>,
#                                                       'skewness': np.float64(-0.4308559205573673),
#                                                       'transverse_cog_uncertainty': None,
#                                                       'width': <Quantity 0.36390359 deg>,
#                                                       'width_uncertainty': <Quantity 0.0164075 deg>},
#                                            'intensity_statistics': {'kurtosis': np.float64(5.358469496553379),
#                                                                     'max': np.int32(33),
#                                                                     'mean': np.float64(4.406685236768802),
#                                                                     'min': np.int32(1),
#                                                                     'skewness': np.float64(2.2384222686592716),
#                                                                     'std': np.float64(5.110103585078069)},
#                                            'leakage': {'intensity_width_1': np.float64(0.02781289506953224),
#                                                        'intensity_width_2': np.float64(0.056890012642225034),
#                                                        'pixels_width_1': np.float64(0.007547169811320755),
#                                                        'pixels_width_2': np.float64(0.014016172506738544)},
#                                            'morphology': {'n_islands': np.int64(45),
#                                                           'n_large_islands': np.int64(1),
#                                                           'n_medium_islands': np.int64(4),
#                                                           'n_pixels': np.int64(359),
#                                                           'n_small_islands': np.int64(40)},
#                                            'peak_time_statistics': {'kurtosis': nan,
#                                                                     'max': np.float32(nan),
#                                                                     'mean': np.float32(nan),
#                                                                     'min': np.float32(nan),
#                                                                     'skewness': nan,
#                                                                     'std': np.float32(nan)},
#                                            'timing': {'deviation': nan,
#                                                       'intercept': nan,
#                                                       'slope': <Quantity nan 1 / deg>}}},
#          np.int16(8): {'impact': {'distance': <Quantity 1030.31800472 m>,
#                                   'distance_uncert': <Quantity 0. m>},
#                        'true_image': array([0, 0, 0, ..., 0, 0, 1], shape=(1855,), dtype=int32),
#                        'true_image_sum': 1239,
#                        'true_parameters': {'concentration': {'cog': np.float64(0.037933817594834544),
#                                                              'core': np.float64(0.48991121872477805),
#                                                              'pixel': np.float64(0.020177562550443905)},
#                                            'core': {'psi': <Quantity nan deg>},
#                                            'hillas': {'fov_lat': <Quantity 0.87333831 deg>,
#                                                       'fov_lon': <Quantity 0.37102561 deg>,
#                                                       'intensity': np.float64(1239.0),
#                                                       'kurtosis': np.float64(2.1417171951174856),
#                                                       'length': <Quantity 1.97001142 deg>,
#                                                       'length_uncertainty': <Quantity 0.02990077 deg>,
#                                                       'phi': <Quantity 66.98246413 deg>,
#                                                       'psi': <Quantity 11.74150385 deg>,
#                                                       'psi_uncertainty': None,
#                                                       'r': <Quantity 0.94888346 deg>,
#                                                       'skewness': np.float64(-0.29777971832916095),
#                                                       'transverse_cog_uncertainty': None,
#                                                       'width': <Quantity 0.38485112 deg>,
#                                                       'width_uncertainty': <Quantity 0.01700711 deg>},
#                                            'intensity_statistics': {'kurtosis': np.float64(5.4820476348802),
#                                                                     'max': np.int32(25),
#                                                                     'mean': np.float64(3.7545454545454544),
#                                                                     'min': np.int32(1),
#                                                                     'skewness': np.float64(2.1695064716664234),
#                                                                     'std': np.float64(3.8820168851279786)},
#                                            'leakage': {'intensity_width_1': np.float64(0.029055690072639227),
#                                                        'intensity_width_2': np.float64(0.06133979015334948),
#                                                        'pixels_width_1': np.float64(0.009703504043126684),
#                                                        'pixels_width_2': np.float64(0.018328840970350403)},
#                                            'morphology': {'n_islands': np.int64(38),
#                                                           'n_large_islands': np.int64(1),
#                                                           'n_medium_islands': np.int64(6),
#                                                           'n_pixels': np.int64(330),
#                                                           'n_small_islands': np.int64(31)},
#                                            'peak_time_statistics': {'kurtosis': nan,
#                                                                     'max': np.float32(nan),
#                                                                     'mean': np.float32(nan),
#                                                                     'min': np.float32(nan),
#                                                                     'skewness': nan,
#                                                                     'std': np.float32(nan)},
#                                            'timing': {'deviation': nan,
#                                                       'intercept': nan,
#                                                       'slope': <Quantity nan 1 / deg>}}}}}

# %%
'''
from ctapipe.io import SimTelEventSource

source = SimTelEventSource("example.simtel.gz")

for event in source:
    r0 = event.r0.tel[tel_id].waveform
'''
# Out:
# '\nfrom ctapipe.io import SimTelEventSource\n\nsource = SimTelEventSource("example.simtel.gz")\n\nfor event in source:\n    r0 = event.r0.tel[tel_id].waveform\n'
